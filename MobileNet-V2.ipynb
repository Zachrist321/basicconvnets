# %% [markdown]
# #### Implementation of MobileNet Architecture
#
# ##### The main purpose of this task is to show transfer learning for mobilenet-v2 architecture

# %%
#importing the necessary libraries
import os
import tensorflow as tf
from tensorflow.keras import layers, models, applications, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd

# %%
# Check if GPU is available in Colab
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# Setting Constant Vars
DATA_DIR = 'image_dataset'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 10

# %%
# Data Augmentation and Loading
datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,
    horizontal_flip=True,
    rotation_range=15
)

train_set = datagen.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training'
)

validation_set = datagen.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 16000 images belonging to 2 classes.
# Found 4000 images belonging to 2 classes.

# %%
#Load the Base MobileNet-V2 Model
base_model = applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
#Build Custom Classification Head
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.2),
    layers.Dense(units=1, activation='sigmoid')
])
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_set,
    validation_data=validation_set,
    epochs=EPOCHS
)
# Out:
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 343s 676ms/step - accuracy: 0.8153 - loss: 0.4071 - val_accuracy: 0.5002 - val_loss: 8.8438
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 339s 678ms/step - accuracy: 0.9213 - loss: 0.1951 - val_accuracy: 0.5000 - val_loss: 15.6235
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 336s 671ms/step - accuracy: 0.9484 - loss: 0.1339 - val_accuracy: 0.5000 - val_loss: 10.4628
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 331s 661ms/step - accuracy: 0.9559 - loss: 0.1151 - val_accuracy: 0.5013 - val_loss: 12.0607
# Epoch 5/10
#  38/500 ━━━━━━━━━━━━━━━━━━━━ 4:46 621ms/step - accuracy: 0.9599 - loss: 0.1205
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 history = model.fit(
#       2     train_set,
#       3     validation_data=validation_set,
#       4     epochs=EPOCHS
#       5 )
#
# ...

# %%
# 7. Save the Finished Model
model.save('face_anti_spoofing_mobilenetv2.h5')
print("✅ Training complete! Model saved.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Training complete! Model saved.

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
