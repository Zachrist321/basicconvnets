# %% [markdown]
# #### Implementation of MobileNet Architecture

# %%
import os
import io
import requests
import tensorflow as tf
from tensorflow.keras import layers, models, applications
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from PIL import Image

# %%
#Load the data
